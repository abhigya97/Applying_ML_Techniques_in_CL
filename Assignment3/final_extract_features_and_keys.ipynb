# %%
import itertools
import re
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Defining functions to get w-2, w-1, w+1, w+2, w−2%w−1, w−1%w+1, w+1%w+2, class.
#
# Special characters are considered seperate words.

# %%
def clean_data(df):
    
    #Stripping the quotes of instance id.
    df['instance_id'] = df['instance_id'].str.strip('"')
    
    #Changing values stored as <head>value<\head> to value.
    
    df = df.replace('<head>', '', regex = True)
    
    df = df.replace('</head>', '', regex = True)
    
    #Replacing ,(comma)
    df = df.replace(',', 'C', regex=True)
    
    #Replacing Nan, if any, with empty string.
    df = df.fillna("")
    
    return df

# %%
def get_matching_string(infile, tempfile, outfile):
    
    
    #Stripping multiple spaces into single space. This means that paragraph information will be lost. 
    #Only way to maintain paragraph information is to split by instance.
    
    fin = open(infile, "rt")
    fout = open(tempfile, "wt")

    for line in fin:
        fout.write(' '.join(line.split()))

    fin.close()
    fout.close()
    
    #Reading the file instance by instance.
    
    with open(tempfile, 'r') as f:
        text = f.read()
        text = text.split("<instance id=")
    
    fout = open(outfile, 'w')
    
    for i in text:
        
        #Matching all occurences of the word in that instance.
    
        matches = re.finditer('(\S+\s){0,2}(<head>\w+</head>)+(\s\S+){0,2}', i)
        
        #The first string will be the instance id as we are splitting at instance id.
        
        match_id = re.search('"\S+"', i)
    
        result = match_id.group(0) if match_id else ""
    
        for m in matches:
             fout.write(result + " " + m.group(0) + '\n')
    
    fout.close()
    
    #Cleaning using pandas dataframe.
    
    df = pd.read_csv(outfile, names=['instance_id','w-2','w-1','w','w+1', 'w+2'], delimiter = ' ')
     
    df = df.drop('w', 1)
    
    df = clean_data(df)
    
    #w−2%w−1 w−1%w+1 w+1%w+2
    
    df['w-2%w-1'] = df.apply(lambda row: row['w-2'] + '%' + row['w-1'], axis=1)
    df['w-1%w+1'] = df.apply(lambda row: row['w-1'] + '%' + row['w+1'], axis=1)
    df['w+1%w+2'] = df.apply(lambda row: row['w+1'] + '%' + row['w+2'], axis=1)
    
    return df

# %%
def get_key(keyfile, key):
    
    #Getting the keys from the file.
    df = pd.read_csv(keyfile, names=['name', 'instance_id', 'senseid', 'senseid2'], delimiter = ' ')
    
    #Taking out all ids for the particular key.
    
    df = df.loc[df['name'] == key]
    
#     #Creating two instances, wherever there are 2 senseids.
#     df = df.sort_index().reset_index(drop=True)
#     d = df.dropna(subset=['senseid2'])
    
#     #counter.
#     c = 0
#     for i in d.index:
        
#         row = df.loc[i + c]
#         df.loc[i+0.5] = row['name'], row['instance_id'], row['senseid2'], np.nan
        
#         df = df.sort_index().reset_index(drop=True)
#         c += 1

        
    #Dropping senseid2. #Considering only the first senseid.
    
    df = df.drop('senseid2', 1)

    return df

# %% [markdown]
# # Defining a function to extract all the examples of the given words.
#
# Code to extract infromation between two word instances was taken from: "https://stackoverflow.com/questions/18865058/extract-values-between-two-strings-in-a-text-file-using-python"

# %%
def extract_content(infile, outfile, start, end, featurefile, tempfile, keyfile, key):
    
    #Dividing our data accroding to the given name. Creating seperate files for each name
    with open(infile, 'r') as f, open(outfile, 'w') as fout:
        while True:
            it = itertools.dropwhile(lambda line: line.strip() != start, f)
            if next(it, None) is None: break
            fout.writelines(itertools.takewhile(lambda line: line.strip() != end, it))
            
    #Getting the features and the keys. 
    
    df1 = get_matching_string(outfile, tempfile, featurefile)
    df2 = get_key(keyfile, key)
    
    #Joining two dataframes on instance id.
    
    df = pd.merge(df1, df2, on = 'instance_id')
    
    #Dropping unnecessary columns.
    
    df = df.drop(['name', 'instance_id'], 1)
    
    return df

# %% [markdown]
# # Defining all the filenames

# %%
infile1 = 'EnglishLS.train/EnglishLS.train'
infile2 = 'EnglishLS.test/EnglishLS.test'


outfile1 = 'arms_train.txt'
outfile2 = 'difficulty_train.txt'
outfile3 = 'interest_train.txt'
outfile4 = 'arms_test.txt'
outfile5 = 'difficulty_test.txt'
outfile6 = 'interest_test.txt'


start1 = '<lexelt item="arm.n">'
start2 = '<lexelt item="difficulty.n">'
start3 = '<lexelt item="interest.n">'


end = '</lexelt>'


tempfile1 = 'arms_train_features_temp.txt'
tempfile2 = 'difficulty_train_features_temp.txt'
tempfile3 = 'interest_train_features_temp.txt'

tempfile4 = 'arms_test_features_temp.txt'
tempfile5 = 'difficulty_test_features_temp.txt'
tempfile6 = 'interest_test_features_temp.txt'


featurefile1 = 'arms_train_features.txt'
featurefile2 = 'difficulty_train_features.txt'
featurefile3 = 'interest_train_features.txt'

featurefile4 = 'arms_test_features.txt'
featurefile5 = 'difficulty_test_features.txt'
featurefile6 = 'interest_test_features.txt'

keyfile1 = 'EnglishLS.train/EnglishLS.train.key'
keyfile2 = 'EnglishLS.test/EnglishLS.test.key'

key1 = 'arm.n'
key2 = 'difficulty.n'
key3 = 'interest.n'

finalfile1 = 'arms_train_final.txt'
finalfile2 = 'difficulty_train_final.txt'
finalfile3 = 'interest_train_final.txt'

finalfile4 = 'arms_test_final.txt'
finalfile5 = 'difficulty_test_final.txt'
finalfile6 = 'interest_test_final.txt'

# %% [markdown]
# # Calling the functions on all 3 training and testing data.

# %%
df1 = extract_content(infile1, outfile1, start1, end, featurefile1, tempfile1, keyfile1, key1)
df2 = extract_content(infile1, outfile2, start2, end, featurefile2, tempfile2, keyfile1, key2)
df3 = extract_content(infile1, outfile3, start3, end, featurefile3, tempfile3, keyfile1, key3)

# %%
df4 = extract_content(infile2, outfile4, start1, end, featurefile4, tempfile4, keyfile2, key1)
df5 = extract_content(infile2, outfile5, start2, end, featurefile5, tempfile5, keyfile2, key2)
df6 = extract_content(infile2, outfile6, start3, end, featurefile6, tempfile6, keyfile2, key3)

# %%
df1
# Out:
#            w-2    w-1            w+1      w+2        w-2%w-1  \
# 0         with  their        chained       to     with%their
# 1        under    his            and     come      under%his
# 2       raised    his  involuntarily        C     raised%his
# 3        under   your            and  wishing     under%your
# 4    searching    for              .     This  searching%for
# ..         ...    ...            ...      ...            ...
# 269     losing    one             or      one     losing%one
# 270       lost     an             or      leg        lost%an
# 271          C    his             by      his          C%his
# 272     pulled     my            out    there      pulled%my
# 273       hand    and        covered     with       hand%and
#
#                w-1%w+1          w+1%w+2        senseid
# 0        their%chained       chained%to  arm%1:08:00::
# 1              his%and         and%come  arm%1:08:00::
# 2    his%involuntarily  involuntarily%C  arm%1:08:00::
# 3             your%and      and%wishing  arm%1:08:00::
# 4                for%.           .%This  arm%1:06:01::
# ..                 ...              ...            ...
# 269             one%or           or%one  arm%1:08:00::
# 270              an%or           or%leg  arm%1:08:00::
# 271             his%by           by%his  arm%1:08:00::
# 272             my%out        out%there  arm%1:08:00::
# 273        and%covered     covered%with  arm%1:08:00::
#
# [274 rows x 8 columns]

# %%
df2
# Out:
#              w-2           w-1          w+1            w+2  \
# 0             of           the           is           that
# 1              I          have           in     continuing
# 2            can       produce           in            the
# 3       although           the      include            the
# 4             in       serious        about        knowing
# 5            may          have           in       deciding
# 6           most       obvious           is           that
# 7    performance          pose          for            the
# 8              C           the          are    complicated
# 9           note         about           of    attribution
# 10         grasp          This          was            the
# 11         first         great           in         making
# 12             a       special         with      portraits
# 13          type            of       arises             in
# 14             .             A           is           that
# 15            of           the           of  disentangling
# 16          with           the           of     aesthetics
# 17         might          have           in     explaining
# 18    recognised       without           in         almost
# 19             C         about  encountered             in
# 20           the          same           as             an
# 21       running          into        about        subsidy
# 22           met  considerable           in         trying
# 23           did          with            C         partly
# 24           too          much            .             Oh
# 25             a        little   explaining           this
# 26          will          have           in        pushing
# 27          very        little           in       learning
# 28          with       special         such             as
# 29            or      personal            C          which
# 30             C         legal          and        housing
# 31            he           has           in      recalling
# 32   bereavement     financial       social          habit
# 33           who           had         with        Flavell
# 34   insuperable             C           is           said
# 35          have         great      holding            off
# 36        Anyone        having          may          leave
# 37            to      physical            C              I
# 38  acknowledges           the           of        writing
# 39            to          real           in          study
# 40            he           has           in        writing
# 41         there           are        about        English
# 42           its     financial            .      Academics
# 43          make     political       within              a
# 44            of           the     students           have
# 45             ;            my         lies             in
# 46          that     potential            C             we
#
#                   w-2%w-1            w-1%w+1           w+1%w+2  \
# 0                  of%the             the%is           is%that
# 1                  I%have            have%in     in%continuing
# 2             can%produce         produce%in            in%the
# 3            although%the        the%include       include%the
# 4              in%serious      serious%about     about%knowing
# 5                may%have            have%in       in%deciding
# 6            most%obvious         obvious%is           is%that
# 7        performance%pose           pose%for           for%the
# 8                   C%the            the%are   are%complicated
# 9              note%about           about%of    of%attribution
# 10             grasp%This           This%was           was%the
# 11            first%great           great%in         in%making
# 12              a%special       special%with    with%portraits
# 13                type%of          of%arises         arises%in
# 14                    .%A               A%is           is%that
# 15                 of%the             the%of  of%disentangling
# 16               with%the             the%of     of%aesthetics
# 17             might%have            have%in     in%explaining
# 18     recognised%without         without%in         in%almost
# 19                C%about  about%encountered    encountered%in
# 20               the%same            same%as             as%an
# 21           running%into         into%about     about%subsidy
# 22       met%considerable    considerable%in         in%trying
# 23               did%with             with%C          C%partly
# 24               too%much             much%.              .%Oh
# 25               a%little  little%explaining   explaining%this
# 26              will%have            have%in        in%pushing
# 27            very%little          little%in       in%learning
# 28           with%special       special%such           such%as
# 29            or%personal         personal%C           C%which
# 30                C%legal          legal%and       and%housing
# 31                 he%has             has%in      in%recalling
# 32  bereavement%financial   financial%social      social%habit
# 33                who%had           had%with      with%Flavell
# 34          insuperable%C               C%is           is%said
# 35             have%great      great%holding       holding%off
# 36          Anyone%having         having%may         may%leave
# 37            to%physical         physical%C               C%I
# 38       acknowledges%the             the%of        of%writing
# 39                to%real            real%in          in%study
# 40                 he%has             has%in        in%writing
# 41              there%are          are%about     about%English
# 42          its%financial        financial%.       .%Academics
# 43         make%political   political%within          within%a
# 44                 of%the       the%students     students%have
# 45                   ;%my            my%lies           lies%in
# 46         that%potential        potential%C              C%we
#
#                  senseid
# 0   difficulty%1:26:00::
# 1   difficulty%1:04:00::
# 2   difficulty%1:09:02::
# 3   difficulty%1:26:00::
# 4   difficulty%1:09:02::
# 5   difficulty%1:04:00::
# 6   difficulty%1:07:00::
# 7   difficulty%1:09:02::
# 8   difficulty%1:09:02::
# 9   difficulty%1:09:02::
# 10  difficulty%1:09:02::
# 11  difficulty%1:04:00::
# 12  difficulty%1:09:02::
# 13  difficulty%1:07:00::
# 14  difficulty%1:09:02::
# 15  difficulty%1:07:00::
# 16  difficulty%1:09:02::
# 17  difficulty%1:09:02::
# 18  difficulty%1:04:00::
# 19  difficulty%1:09:02::
# 20  difficulty%1:09:02::
# 21  difficulty%1:26:00::
# 22  difficulty%1:26:00::
# 23  difficulty%1:04:00::
# 24  difficulty%1:04:00::
# 25  difficulty%1:04:00::
# 26  difficulty%1:26:00::
# 27  difficulty%1:04:00::
# 28  difficulty%1:26:00::
# 29  difficulty%1:26:00::
# 30  difficulty%1:26:00::
# 31  difficulty%1:04:00::
# 32  difficulty%1:26:00::
# 33  difficulty%1:04:00::
# 34  difficulty%1:09:02::
# 35  difficulty%1:04:00::
# 36  difficulty%1:04:00::
# 37  difficulty%1:26:00::
# 38  difficulty%1:07:00::
# 39  difficulty%1:04:00::
# 40  difficulty%1:04:00::
# 41  difficulty%1:26:00::
# 42  difficulty%1:26:00::
# 43  difficulty%1:26:00::
# 44  difficulty%1:04:00::
# 45  difficulty%1:04:00::
# 46  difficulty%1:07:00::

# %%
df3
# Out:
#           w-2         w-1 w+1            w+2           w-2%w-1        w-1%w+1  \
# 0     Serving         the  of  Haemophiliacs       Serving%the         the%of
# 1         and         the  of        clients           and%the         the%of
# 2         and      shared   C            not        and%shared       shared%C
# 3    building     society  on          which  building%society     society%on
# 4    building     society  on          which  building%society     society%on
# ..        ...         ...  ..            ...               ...            ...
# 183     shown  increasing  in             it  shown%increasing  increasing%in
# 184       one          's  to           have            one%'s          's%to
# 185       the      public   .            The        the%public       public%.
# 186      only          of  to          three           only%of          of%to
# 187       has   expressed  in       refining     has%expressed   expressed%in
#
#               w+1%w+2             senseid
# 0    of%Haemophiliacs  interest%1:07:01::
# 1          of%clients  interest%1:07:01::
# 2               C%not  interest%1:04:01::
# 3            on%which  interest%1:21:00::
# 4            on%which  interest%1:21:00::
# ..                ...                 ...
# 183             in%it  interest%1:09:00::
# 184           to%have  interest%1:07:01::
# 185             .%The  interest%1:07:01::
# 186          to%three  interest%1:07:02::
# 187       in%refining  interest%1:09:00::
#
# [188 rows x 8 columns]

# %%
df4
# Out:
#          w-2       w-1    w+1        w+2       w-2%w-1      w-1%w+1  \
# 0       with       six     as       Siva      with%six       six%as
# 1        all       his      C        And       all%his        his%C
# 2         of    folded      C        The     of%folded     folded%C
# 3      above       the     of        the     above%the       the%of
# 4        the  sparging     at        the  the%sparging  sparging%at
# ..       ...       ...    ...        ...           ...          ...
# 128     side         -      C  sometimes        side%-          -%C
# 129   waving       his  about        and    waving%his    his%about
# 130  drawing       his     in          a   drawing%his       his%in
# 131   washed        my     in        the     washed%my        my%in
# 132   waving       his      .        You    waving%his        his%.
#
#          w+1%w+2        senseid
# 0        as%Siva  arm%1:08:00::
# 1          C%And  arm%1:08:00::
# 2          C%The  arm%1:08:00::
# 3         of%the  arm%1:06:03::
# 4         at%the              U
# ..           ...            ...
# 128  C%sometimes  arm%1:06:01::
# 129    about%and  arm%1:08:00::
# 130         in%a  arm%1:08:00::
# 131       in%the  arm%1:08:00::
# 132        .%You  arm%1:08:00::
#
# [133 rows x 8 columns]

# %%
df5
# Out:
#              w-2         w-1      w+1            w+2                w-2%w-1  \
# 0        produce       great       in            the          produce%great
# 1      encounter        many     with            our         encounter%many
# 2             of         her       is             to                 of%her
# 3           find        more       in      following              find%more
# 4         seldom     without        )           when         seldom%without
# 5              :         his       is      assessing                  :%his
# 6            The       first       is              C              The%first
# 7              .         One       in     describing                  .%One
# 8     constantly   presented       to        critics   constantly%presented
# 9           some  tormenting        C            His        some%tormenting
# 10            is           a     that         Justin                   is%a
# 11           had          no       in        telling                 had%no
# 12   obscurities         and       of          words        obscurities%and
# 13             .         The       is           that                  .%The
# 14             .         The      was              C                  .%The
# 15             .         The       is           that                  .%The
# 16           get        into     when           they               get%into
# 17  anticipation    prevents  arising              .  anticipation%prevents
# 18          with    learning        .           Help          with%learning
# 19            he         had       in  concentrating                 he%had
# 20           the     obvious      and   frustrations            the%obvious
# 21             .        Much    could             be                 .%Much
# 22            do     present      and              I             do%present
#
#              w-1%w+1           w+1%w+2               senseid
# 0           great%in            in%the  difficulty%1:04:00::
# 1          many%with          with%our  difficulty%1:09:02::
# 2             her%is             is%to  difficulty%1:07:00::
# 3            more%in      in%following  difficulty%1:04:00::
# 4          without%)            )%when  difficulty%1:26:00::
# 5             his%is      is%assessing  difficulty%1:09:02::
# 6           first%is              is%C  difficulty%1:09:02::
# 7             One%in     in%describing  difficulty%1:09:02::
# 8       presented%to        to%critics  difficulty%1:09:02::
# 9       tormenting%C             C%His  difficulty%1:26:00::
# 10            a%that       that%Justin  difficulty%1:26:00::
# 11             no%in        in%telling  difficulty%1:04:00::
# 12            and%of          of%words  difficulty%1:09:02::
# 13            The%is           is%that                     U
# 14           The%was             was%C  difficulty%1:26:00::
# 15            The%is           is%that  difficulty%1:26:00::
# 16         into%when         when%they  difficulty%1:26:00::
# 17  prevents%arising         arising%.  difficulty%1:26:00::
# 18        learning%.            .%Help  difficulty%1:26:00::
# 19            had%in  in%concentrating  difficulty%1:04:00::
# 20       obvious%and  and%frustrations  difficulty%1:09:02::
# 21        Much%could          could%be  difficulty%1:07:00::
# 22       present%and             and%I  difficulty%1:09:02::

# %%
df6
# Out:
#           w-2         w-1     w+1         w+2         w-2%w-1  \
# 0           C    mortgage  relief           C      C%mortgage
# 1           C    economic     and   religious      C%economic
# 2           .         Her     has        been           .%Her
# 3         and  persistent   which       human  and%persistent
# 4   indicated          an      in         the    indicated%an
# ..        ...         ...     ...         ...             ...
# 88        the      public     for  challenges      the%public
# 89      serve         the      of         the       serve%the
# 90          a   financial      in      United     a%financial
# 91          a   financial      in     another     a%financial
# 92         in         the      of    personal          in%the
#
#              w-1%w+1         w+1%w+2             senseid
# 0    mortgage%relief        relief%C  interest%1:21:00::
# 1       economic%and   and%religious  interest%1:07:01::
# 2            Her%has        has%been  interest%1:04:01::
# 3   persistent%which     which%human  interest%1:09:00::
# 4              an%in          in%the  interest%1:09:00::
# ..               ...             ...                 ...
# 88        public%for  for%challenges  interest%1:07:01::
# 89            the%of          of%the  interest%1:07:01::
# 90      financial%in       in%United  interest%1:21:03::
# 91      financial%in      in%another  interest%1:21:03::
# 92            the%of     of%personal  interest%1:07:01::
#
# [93 rows x 8 columns]

# %% [markdown]
# # Saving final training and testing files.

# %%
df1.to_csv(finalfile1, sep=',', index=False, header = False)

# %%
df2.to_csv(finalfile2, sep=',', index=False, header = False)

# %%
df3.to_csv(finalfile3, sep=',', index=False, header = False)

# %%
df4.to_csv(finalfile4, sep=',', index=False, header = False)

# %%
df5.to_csv(finalfile5, sep=',', index=False, header = False)

# %%
df6.to_csv(finalfile6, sep=',', index=False, header = False)

# %% [markdown]
# # Removing the temporary files created.

# %%
os.remove(outfile1)
os.remove(outfile2)
os.remove(outfile3)

os.remove(outfile4)
os.remove(outfile5)
os.remove(outfile6)

os.remove(featurefile1)
os.remove(featurefile2)
os.remove(featurefile3)

os.remove(featurefile4)
os.remove(featurefile5)
os.remove(featurefile6)

os.remove(tempfile1)
os.remove(tempfile2)
os.remove(tempfile3)

os.remove(tempfile4)
os.remove(tempfile5)
os.remove(tempfile6)
